# %% [markdown]
# # Web Scraping Student
# ## For: Michel Souza Santana
# > Date start: 01/02/2022
#
# * The purpose of this is to record the process of learning the WebScraping technique and make it available to anyone who wants to make use of it for their own development.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import collections

# %%
df = pd.read_csv('/home/kali/Documentos/PROJETOS_ESTUDO/Imobiliario-BC-Regiao/imobiliario.csv')
df.head()
# Out:
#    Unnamed: 0                cidade             bairro estado  tipo_imovel  \
# 0           0               Itajaí   Praia dos Amores      SC  Apartamento
# 1           1               Itajaí        Praia Brava      SC  Apartamento
# 2           2               Itajaí        Praia Brava      SC  Apartamento
# 3           3   Balneário Camboriú             Centro      SC  Apartamento
# 4           4   Balneário Camboriú             Centro      SC  Apartamento
#
#        m2  quartos  suites  banheiros  vagas       preco
# 0  203.53        4       4          1      2  7200000.00
# 1  185.12        3       3          1      3  5926273.63
# 2  210.00        4       4          1      4  6089548.34
# 3  317.10        4       2          1      2  3300000.00
# 4  185.63        3       3          4      4  6950000.00

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.shape
# Out:
# (483, 10)

# %%
df.isnull().sum()
# Out:
# cidade         0
# bairro         0
# estado         0
# tipo_imovel    0
# m2             0
# quartos        0
# suites         0
# banheiros      0
# vagas          0
# preco          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 18

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (465, 10)

# %%
df.head()
# Out:
#                  cidade             bairro estado  tipo_imovel      m2  \
# 0               Itajaí   Praia dos Amores      SC  Apartamento  203.53
# 1               Itajaí        Praia Brava      SC  Apartamento  185.12
# 2               Itajaí        Praia Brava      SC  Apartamento  210.00
# 3   Balneário Camboriú             Centro      SC  Apartamento  317.10
# 4   Balneário Camboriú             Centro      SC  Apartamento  185.63
#
#    quartos  suites  banheiros  vagas       preco
# 0        4       4          1      2  7200000.00
# 1        3       3          1      3  5926273.63
# 2        4       4          1      4  6089548.34
# 3        4       2          1      2  3300000.00
# 4        3       3          4      4  6950000.00

# %%
df.loc[df['tipo_imovel'] == 'Sítio']
# Out:
#          cidade               bairro estado tipo_imovel        m2  quartos  \
# 316   Camboriú   Bairro Rio Pequeno      SC       Sítio  28650.74        3
#
#      suites  banheiros  vagas      preco
# 316       1          3      2  4000000.0

# %%
df.drop([300], inplace=True)

# %%
df_m2 = pd.DataFrame.sort_values(df, by=['m2'], ascending=False).head(10)
df_m2
# Out:
#                    cidade                 bairro estado  tipo_imovel  \
# 316             Camboriú     Bairro Rio Pequeno      SC        Sítio
# 399   Balneário Camboriú                  Barra      SC         Casa
# 404   Balneário Camboriú   Frente Mar Barra Sul      SC    Cobertura
# 52                Itajaí            Praia Brava      SC  Apartamento
# 311   Balneário Camboriú   Frente Mar Barra Sul      SC    Cobertura
# 5     Balneário Camboriú     Praia do Estaleiro      SC         Casa
# 435              Itapema             Meia Praia      SC    Cobertura
# 75               Itapema             Meia Praia      SC  Apartamento
# 469   Balneário Camboriú             Frente Mar      SC  Apartamento
# 56              Camboriú                 Centro      SC         Casa
#
#            m2  quartos  suites  banheiros  vagas        preco
# 316  28650.74        3       1          3      2   4000000.00
# 399    753.00        5       5          8      5   8500000.00
# 404    600.00        6       6          6      4  21400000.00
# 52     548.14        4       4          1      3   8209224.83
# 311    475.00        6       6          8      6  24900000.00
# 5      458.00        5       4          1      4  20000000.00
# 435    427.44        5       5          5      4  14541000.00
# 75     427.44        5       5          1      4  14860000.00
# 469    380.00        4       3          5      2   6300000.00
# 56     370.00        3       3          3      3   3750000.00

# %%
corr = df[['m2', 'quartos', 'suites', 'banheiros', 'preco']]

# %%
corr.corr()
# Out:
#                  m2   quartos    suites  banheiros     preco
# m2         1.000000  0.021373 -0.038568   0.039260  0.052794
# quartos    0.021373  1.000000  0.779356   0.275429  0.629791
# suites    -0.038568  0.779356  1.000000   0.344135  0.622361
# banheiros  0.039260  0.275429  0.344135   1.000000  0.321744
# preco      0.052794  0.629791  0.622361   0.321744  1.000000

# %%
df.describe()
# Out:
#                  m2     quartos      suites   banheiros       vagas  \
# count    464.000000  464.000000  464.000000  464.000000  464.000000
# mean     225.319763    3.312500    2.900862    2.377155    2.625000
# std     1324.846269    0.807213    1.178863    1.567073    1.044113
# min       55.000000    1.000000    1.000000    1.000000    1.000000
# 25%      122.620000    3.000000    2.000000    1.000000    2.000000
# 50%      146.000000    3.000000    3.000000    2.000000    3.000000
# 75%      185.247500    4.000000    4.000000    4.000000    3.000000
# max    28650.740000    6.000000    6.000000    8.000000    8.000000
#
#               preco
# count  4.640000e+02
# mean   3.530252e+06
# std    2.905202e+06
# min    0.000000e+00
# 25%    1.780000e+06
# 50%    2.755500e+06
# 75%    4.510500e+06
# max    2.490000e+07

# %%
collections.Counter(df['preco'] == 0)
# Out:
# Counter({False: 463, True: 1})

# %%
df.loc[df['preco'] == 0, 'preco'] = None

# %%
df.isnull().sum()
# Out:
# cidade         0
# bairro         0
# estado         0
# tipo_imovel    0
# m2             0
# quartos        0
# suites         0
# banheiros      0
# vagas          0
# preco          1
# dtype: int64

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#                  m2     quartos      suites   banheiros       vagas  \
# count    463.000000  463.000000  463.000000  463.000000  463.000000
# mean     225.386868    3.311015    2.898488    2.373650    2.624190
# std     1326.278521    0.807452    1.179028    1.566947    1.045097
# min       55.000000    1.000000    1.000000    1.000000    1.000000
# 25%      122.540000    3.000000    2.000000    1.000000    2.000000
# 50%      146.000000    3.000000    3.000000    2.000000    3.000000
# 75%      185.060000    4.000000    4.000000    4.000000    3.000000
# max    28650.740000    6.000000    6.000000    8.000000    8.000000
#
#               preco
# count  4.630000e+02
# mean   3.537877e+06
# std    2.903693e+06
# min    5.500000e+05
# 25%    1.781927e+06
# 50%    2.761000e+06
# 75%    4.521000e+06
# max    2.490000e+07

# %%
df_preco = df.sort_values(by=('preco'), ascending=False).head(10)
df_preco
# Out:
#                    cidade                 bairro estado  tipo_imovel      m2  \
# 311   Balneário Camboriú   Frente Mar Barra Sul      SC    Cobertura  475.00
# 404   Balneário Camboriú   Frente Mar Barra Sul      SC    Cobertura  600.00
# 5     Balneário Camboriú     Praia do Estaleiro      SC         Casa  458.00
# 75               Itapema             Meia Praia      SC  Apartamento  427.44
# 115   Balneário Camboriú                 Centro      SC  Apartamento  287.34
# 435              Itapema             Meia Praia      SC    Cobertura  427.44
# 177   Balneário Camboriú                 Centro      SC  Apartamento  361.20
# 229               Itajaí            Praia Brava      SC  Apartamento  350.00
# 403               Itajaí            Praia Brava      SC  Apartamento  350.00
# 256   Balneário Camboriú                 Centro      SC  Apartamento  230.86
#
#      quartos  suites  banheiros  vagas       preco
# 311        6       6          8      6  24900000.0
# 404        6       6          6      4  21400000.0
# 5          5       4          1      4  20000000.0
# 75         5       5          1      4  14860000.0
# 115        4       4          1      5  14750000.0
# 435        5       5          5      4  14541000.0
# 177        4       4          1      3  13046103.0
# 229        5       5          5      5  12800000.0
# 403        5       5          5      5  12500000.0
# 256        4       4          4      4  11750000.0

# %%
df_merge = df_preco.merge(df_m2)

# %%
df_merge
# Out:
#                  cidade                 bairro estado  tipo_imovel      m2  \
# 0   Balneário Camboriú   Frente Mar Barra Sul      SC    Cobertura  475.00
# 1   Balneário Camboriú   Frente Mar Barra Sul      SC    Cobertura  600.00
# 2   Balneário Camboriú     Praia do Estaleiro      SC         Casa  458.00
# 3              Itapema             Meia Praia      SC  Apartamento  427.44
# 4              Itapema             Meia Praia      SC    Cobertura  427.44
#
#    quartos  suites  banheiros  vagas       preco
# 0        6       6          8      6  24900000.0
# 1        6       6          6      4  21400000.0
# 2        5       4          1      4  20000000.0
# 3        5       5          1      4  14860000.0
# 4        5       5          5      4  14541000.0

# %%
df_agrupado = df.groupby(['cidade'])['preco'].mean().to_frame().sort_values(by=['preco'], ascending=False).reset_index()
df_agrupado
# Out:
#                  cidade         preco
# 0              Itapema   8.268200e+06
# 1               Itajaí   4.227048e+06
# 2   Balneário Camboriú   3.584330e+06
# 3             Camboriú   1.082120e+06

# %%
df['cidade'].unique()
# Out:
# array([' Itajaí ', ' Balneário Camboriú ', ' Camboriú ', ' Itapema '],
#       dtype=object)

# %%
df_itapema = df.loc[df['cidade'] == ' Itapema '].sort_values(by=['preco'], ascending=False).head(10)
df_itapema
# Out:
#         cidade       bairro estado  tipo_imovel      m2  quartos  suites  \
# 75    Itapema   Meia Praia      SC  Apartamento  427.44        5       5
# 435   Itapema   Meia Praia      SC    Cobertura  427.44        5       5
# 76    Itapema   Meia Praia      SC  Apartamento  213.72        4       4
# 73    Itapema   Meia Praia      SC  Apartamento  213.72        4       4
# 436   Itapema   Meia Praia      SC  Apartamento  213.72        4       4
#
#      banheiros  vagas       preco
# 75           1      4  14860000.0
# 435          5      4  14541000.0
# 76           1      3   4150000.0
# 73           1      3   3940000.0
# 436          4      3   3850000.0

# %%
df_bc = df.loc[df['cidade'] == ' Balneário Camboriú '].sort_values(by=['preco'], ascending=False).head(10)
df_bc
# Out:
#                    cidade                 bairro estado  tipo_imovel      m2  \
# 311   Balneário Camboriú   Frente Mar Barra Sul      SC    Cobertura  475.00
# 404   Balneário Camboriú   Frente Mar Barra Sul      SC    Cobertura  600.00
# 5     Balneário Camboriú     Praia do Estaleiro      SC         Casa  458.00
# 115   Balneário Camboriú                 Centro      SC  Apartamento  287.34
# 177   Balneário Camboriú                 Centro      SC  Apartamento  361.20
# 256   Balneário Camboriú                 Centro      SC  Apartamento  230.86
# 348   Balneário Camboriú              Barra Sul      SC  Apartamento  226.61
# 13    Balneário Camboriú                 Centro      SC  Apartamento  238.00
# 325   Balneário Camboriú   Frente Mar Barra Sul      SC  Apartamento  237.00
# 324   Balneário Camboriú   Frente Mar Barra Sul      SC  Apartamento  238.00
#
#      quartos  suites  banheiros  vagas       preco
# 311        6       6          8      6  24900000.0
# 404        6       6          6      4  21400000.0
# 5          5       4          1      4  20000000.0
# 115        4       4          1      5  14750000.0
# 177        4       4          1      3  13046103.0
# 256        4       4          4      4  11750000.0
# 348        4       4          5      2  10895000.0
# 13         4       4          1      4  10500000.0
# 325        4       4          4      4  10300000.0
# 324        4       4          4      4  10300000.0

# %%
df_itajai = df.loc[df['cidade'] == ' Itajaí '].sort_values(by=['preco'], ascending=False).head(10)
df_itajai
# Out:
#        cidade             bairro estado  tipo_imovel      m2  quartos  suites  \
# 229   Itajaí        Praia Brava      SC  Apartamento  350.00        5       5
# 403   Itajaí        Praia Brava      SC  Apartamento  350.00        5       5
# 266   Itajaí        Praia Brava      SC  Apartamento  226.07        4       4
# 326   Itajaí        Praia Brava      SC  Apartamento  268.00        4       4
# 265   Itajaí        Praia Brava      SC  Apartamento  226.07        4       4
# 166   Itajaí        Praia Brava      SC  Apartamento  226.00        4       4
# 52    Itajaí        Praia Brava      SC  Apartamento  548.14        4       4
# 328   Itajaí        Praia Brava      SC  Apartamento  207.00        4       4
# 0     Itajaí   Praia dos Amores      SC  Apartamento  203.53        4       4
# 51    Itajaí        Praia Brava      SC  Apartamento  361.58        4       4
#
#      banheiros  vagas        preco
# 229          5      5  12800000.00
# 403          5      5  12500000.00
# 266          1      4   9325179.16
# 326          4      4   9300000.00
# 265          1      4   9222179.78
# 166          1      4   8400000.00
# 52           1      3   8209224.83
# 328          4      4   7400000.00
# 0            1      2   7200000.00
# 51           1      4   7091211.98

# %%
df_camboriu = df.loc[df['cidade'] == ' Camboriú '].sort_values(by=['preco'], ascending=False).head(10)
df_camboriu
# Out:
#          cidade                   bairro estado  tipo_imovel        m2  \
# 316   Camboriú       Bairro Rio Pequeno      SC        Sítio  28650.74
# 56    Camboriú                   Centro      SC         Casa    370.00
# 454   Camboriú             Santa Regina      SC         Casa    233.02
# 329   Camboriú                   Centro      SC      Sobrado    180.00
# 351   Camboriú   São Francisco de Assis      SC  Apartamento    116.00
# 350   Camboriú   São Francisco de Assis      SC  Apartamento    120.00
# 112   Camboriú                Tabuleiro      SC  Apartamento     98.84
# 106   Camboriú                Tabuleiro      SC  Apartamento     96.93
# 113   Camboriú                Tabuleiro      SC  Apartamento     93.87
# 104   Camboriú                Tabuleiro      SC  Apartamento     93.94
#
#      quartos  suites  banheiros  vagas       preco
# 316        3       1          3      2  4000000.00
# 56         3       3          3      3  3750000.00
# 454        3       3          3      5  2500000.00
# 329        3       1          3      3  1400000.00
# 351        3       1          1      2  1000000.00
# 350        3       1          1      2  1000000.00
# 112        2       2          1      1   999631.44
# 106        3       1          1      2   969367.79
# 113        2       2          1      1   951639.17
# 104        3       1          1      2   931767.12

# %%
df_top = pd.concat([df_itapema, df_bc, df_itajai, df_camboriu], axis=0, join='inner')

# %%
df_top
# Out:
#                    cidade                   bairro estado  tipo_imovel  \
# 75               Itapema               Meia Praia      SC  Apartamento
# 435              Itapema               Meia Praia      SC    Cobertura
# 76               Itapema               Meia Praia      SC  Apartamento
# 73               Itapema               Meia Praia      SC  Apartamento
# 436              Itapema               Meia Praia      SC  Apartamento
# 311   Balneário Camboriú     Frente Mar Barra Sul      SC    Cobertura
# 404   Balneário Camboriú     Frente Mar Barra Sul      SC    Cobertura
# 5     Balneário Camboriú       Praia do Estaleiro      SC         Casa
# 115   Balneário Camboriú                   Centro      SC  Apartamento
# 177   Balneário Camboriú                   Centro      SC  Apartamento
# 256   Balneário Camboriú                   Centro      SC  Apartamento
# 348   Balneário Camboriú                Barra Sul      SC  Apartamento
# 13    Balneário Camboriú                   Centro      SC  Apartamento
# 325   Balneário Camboriú     Frente Mar Barra Sul      SC  Apartamento
# 324   Balneário Camboriú     Frente Mar Barra Sul      SC  Apartamento
# 229               Itajaí              Praia Brava      SC  Apartamento
# 403               Itajaí              Praia Brava      SC  Apartamento
# 266               Itajaí              Praia Brava      SC  Apartamento
# 326               Itajaí              Praia Brava      SC  Apartamento
# 265               Itajaí              Praia Brava      SC  Apartamento
# 166               Itajaí              Praia Brava      SC  Apartamento
# 52                Itajaí              Praia Brava      SC  Apartamento
# 328               Itajaí              Praia Brava      SC  Apartamento
# 0                 Itajaí         Praia dos Amores      SC  Apartamento
# 51                Itajaí              Praia Brava      SC  Apartamento
# 316             Camboriú       Bairro Rio Pequeno      SC        Sítio
# 56              Camboriú                   Centro      SC         Casa
# 454             Camboriú             Santa Regina      SC         Casa
# 329             Camboriú                   Centro      SC      Sobrado
# 351             Camboriú   São Francisco de Assis      SC  Apartamento
# 350             Camboriú   São Francisco de Assis      SC  Apartamento
# 112             Camboriú                Tabuleiro      SC  Apartamento
# 106             Camboriú                Tabuleiro      SC  Apartamento
# 113             Camboriú                Tabuleiro      SC  Apartamento
# 104             Camboriú                Tabuleiro      SC  Apartamento
#
#            m2  quartos  suites  banheiros  vagas        preco
# 75     427.44        5       5          1      4  14860000.00
# 435    427.44        5       5          5      4  14541000.00
# 76     213.72        4       4          1      3   4150000.00
# 73     213.72        4       4          1      3   3940000.00
# 436    213.72        4       4          4      3   3850000.00
# 311    475.00        6       6          8      6  24900000.00
# 404    600.00        6       6          6      4  21400000.00
# 5      458.00        5       4          1      4  20000000.00
# 115    287.34        4       4          1      5  14750000.00
# 177    361.20        4       4          1      3  13046103.00
# 256    230.86        4       4          4      4  11750000.00
# 348    226.61        4       4          5      2  10895000.00
# 13     238.00        4       4          1      4  10500000.00
# 325    237.00        4       4          4      4  10300000.00
# 324    238.00        4       4          4      4  10300000.00
# 229    350.00        5       5          5      5  12800000.00
# 403    350.00        5       5          5      5  12500000.00
# 266    226.07        4       4          1      4   9325179.16
# 326    268.00        4       4          4      4   9300000.00
# 265    226.07        4       4          1      4   9222179.78
# 166    226.00        4       4          1      4   8400000.00
# 52     548.14        4       4          1      3   8209224.83
# 328    207.00        4       4          4      4   7400000.00
# 0      203.53        4       4          1      2   7200000.00
# 51     361.58        4       4          1      4   7091211.98
# 316  28650.74        3       1          3      2   4000000.00
# 56     370.00        3       3          3      3   3750000.00
# 454    233.02        3       3          3      5   2500000.00
# 329    180.00        3       1          3      3   1400000.00
# 351    116.00        3       1          1      2   1000000.00
# 350    120.00        3       1          1      2   1000000.00
# 112     98.84        2       2          1      1    999631.44
# 106     96.93        3       1          1      2    969367.79
# 113     93.87        2       2          1      1    951639.17
# 104     93.94        3       1          1      2    931767.12

# %%
m_m2 = float(df_top['m2'].mean())
m_quartos = float(df_top['quartos'].mean())
m_vagas = float(df_top['vagas'].mean())
m_preco = float(df_top['preco'].mean())
print(f'Média de m2 {m_m2:.2f}')
print(f'Média de quartos {m_quartos:.2f}')
print(f'Média de vagas {m_vagas:.2f}')
print(f'Média de preco {m_preco:.2f}')
# Out:
# Média de m2 1081.94
# Média de quartos 3.91
# Média de vagas 3.40
# Média de preco 8518065.84

# %%
df_melhor_custo = df_top.loc[df_top['preco'] <= (m_preco + 2000000)]
df_melhor_custo = df_melhor_custo.loc[df_melhor_custo['preco'] >= (m_preco - 2000000)]
df_melhor_custo
# Out:
#                    cidade                 bairro estado  tipo_imovel      m2  \
# 13    Balneário Camboriú                 Centro      SC  Apartamento  238.00
# 325   Balneário Camboriú   Frente Mar Barra Sul      SC  Apartamento  237.00
# 324   Balneário Camboriú   Frente Mar Barra Sul      SC  Apartamento  238.00
# 266               Itajaí            Praia Brava      SC  Apartamento  226.07
# 326               Itajaí            Praia Brava      SC  Apartamento  268.00
# 265               Itajaí            Praia Brava      SC  Apartamento  226.07
# 166               Itajaí            Praia Brava      SC  Apartamento  226.00
# 52                Itajaí            Praia Brava      SC  Apartamento  548.14
# 328               Itajaí            Praia Brava      SC  Apartamento  207.00
# 0                 Itajaí       Praia dos Amores      SC  Apartamento  203.53
# 51                Itajaí            Praia Brava      SC  Apartamento  361.58
#
#      quartos  suites  banheiros  vagas        preco
# 13         4       4          1      4  10500000.00
# 325        4       4          4      4  10300000.00
# 324        4       4          4      4  10300000.00
# 266        4       4          1      4   9325179.16
# 326        4       4          4      4   9300000.00
# 265        4       4          1      4   9222179.78
# 166        4       4          1      4   8400000.00
# 52         4       4          1      3   8209224.83
# 328        4       4          4      4   7400000.00
# 0          4       4          1      2   7200000.00
# 51         4       4          1      4   7091211.98
